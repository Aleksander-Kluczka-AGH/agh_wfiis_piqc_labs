# %%
from qiskit import QuantumCircuit
from qiskit import Aer
from qiskit.tools.visualization import plot_histogram, plot_state_city

N = 5

circuit = QuantumCircuit(N, N)

for i in range(N):
    circuit.h(i)
    circuit.measure(i, i)

backend = Aer.get_backend("aer_simulator")

job = backend.run(circuit)

result = job.result()
counts = result.get_counts(circuit)
print(counts)

circuit.draw("mpl")
# Out:
# {'00001': 36, '10000': 39, '10010': 24, '00011': 34, '11011': 27, '00110': 43, '01111': 42, '10011': 40, '10100': 28, '11111': 24, '00101': 40, '10110': 33, '11100': 32, '00010': 35, '01000': 31, '10101': 26, '00100': 30, '01100': 32, '10111': 28, '01010': 27, '01001': 27, '11110': 29, '00000': 32, '01110': 44, '11001': 32, '11000': 35, '11101': 34, '00111': 26, '10001': 34, '01101': 30, '01011': 29, '11010': 21}
# C:\Users\alaga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\qiskit\visualization\circuit\matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
from qiskit.visualization import plot_histogram

plot_histogram(counts)

# %% [markdown]
# ## Homework

# %%
from qiskit import IBMQ

provider = IBMQ.load_account()
IBMQ.providers()
# Out:
# C:\Users\alaga\AppData\Local\Temp\ipykernel_12148\2506897133.py:3: DeprecationWarning: The package qiskit.providers.ibmq is being deprecated. Please see https://ibm.biz/provider_migration_guide to get instructions on how to migrate to qiskit-ibm-provider (https://github.com/Qiskit/qiskit-ibm-provider) and qiskit-ibm-runtime (https://github.com/Qiskit/qiskit-ibm-runtime).
#   provider = IBMQ.load_account()
# C:\Users\alaga\AppData\Local\Temp\ipykernel_12148\2506897133.py:3: DeprecationWarning: The qiskit.IBMQ entrypoint and the qiskit-ibmq-provider package (accessible from 'qiskit.providers.ibmq`) are deprecated and will be removed in a future release. Instead you should use the qiskit-ibm-provider package which is accessible from 'qiskit_ibm_provider'. You can install it with 'pip install qiskit_ibm_provider'. Just replace 'qiskit.IBMQ' with 'qiskit_ibm_provider.IBMProvider'
#   provider = IBMQ.load_account()
# [<AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>]

# %%
provider.backends()
# Out:
# [<IBMQSimulator('ibmq_qasm_simulator') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQSimulator('simulator_statevector') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQSimulator('simulator_mps') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQSimulator('simulator_extended_stabilizer') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQSimulator('simulator_stabilizer') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibm_lagos') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibm_nairobi') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibm_perth') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibm_brisbane') from IBMQ(hub='ibm-q', group='open', project='main')>]

# %%
sim_backend = provider.get_backend("ibmq_qasm_simulator")

# %%
from qiskit.tools.monitor import backend_overview, backend_monitor

backend_overview()
# Out:
# ibm_brisbane                 ibm_perth                    ibm_nairobi
# ------------                 ---------                    -----------
# Num. Qubits:  127            Num. Qubits:  7              Num. Qubits:  7
# Pending Jobs: 1259           Pending Jobs: 714            Pending Jobs: 284
# Least busy:   False          Least busy:   False          Least busy:   True
# Operational:  True           Operational:  True           Operational:  True
# Avg. T1:      219.0          Avg. T1:      129.6          Avg. T1:      101.3
# Avg. T2:      148.8          Avg. T2:      175.7          Avg. T2:      68.1
#
#
#
# ibm_lagos
# ---------
# Num. Qubits:  7
# Pending Jobs: 326
# Least busy:   False
# Operational:  True
# Avg. T1:      107.6
# Avg. T2:      76.2

# %%
from pprint import pprint

pprint(sim_backend.configuration().to_dict())
# Out:
# {'allow_object_storage': True,
#  'allow_q_object': True,
#  'backend_name': 'ibmq_qasm_simulator',
#  'backend_version': '0.1.547',
#  'basis_gates': ['u1',
#                  'u2',
#                  'u3',
#                  'u',
#                  'p',
#                  'r',
#                  'rx',
#                  'ry',
#                  'rz',
#                  'cx',
#                  'cy',
#                  'cz',
#                  'csx',
#                  'cp',
#                  'id',
#                  'x',
#                  'y',
#                  'z',
#                  'h',
#                  's',
#                  'sdg',
#                  'sx',
#                  't',
#                  'tdg',
#                  'swap',
#                  'ccx',
#                  'cswap',
#                  'unitary',
#                  'diagonal',
#                  'initialize',
#                  'cu1',
#                  'cu2',
#                  'cu3',
#                  'rxx',
#                  'ryy',
#                  'rzz',
#                  'rzx',
#                  'mcx',
#                  'mcy',
#                  'mcz',
#                  'mcsx',
#                  'mcp',
#                  'mcu1',
#                  'mcu2',
#                  'mcu3',
#                  'mcrx',
#                  'mcry',
#                  'mcrz',
#                  'mcr',
#                  'mcswap',
#                  'multiplexer',
#                  'kraus',
#                  'delay',
#                  'roerror'],
#  'conditional': True,
#  'coupling_map': None,
#  'dynamic_reprate_enabled': False,
#  'gates': [{'conditional': True,
#             'description': 'Single-qubit gate [[1, 0], [0, exp(1j*lam)]]',
#             'name': 'u1',
#             'parameters': ['lam'],
#             'qasm_def': 'gate u1(lam) q { U(0,0,lam) q; }'},
#            {'conditional': True,
#             'description': 'Single-qubit gate [[1, -exp(1j*lam)], '
#                            '[exp(1j*phi), exp(1j*(phi+lam))]]/sqrt(2)',
#             'name': 'u2',
#             'parameters': ['phi', 'lam'],
#             'qasm_def': 'gate u2(phi,lam) q { U(pi/2,phi,lam) q; }'},
#            {'conditional': True,
#             'description': 'Single-qubit gate with three rotation angles',
#             'name': 'u3',
#             'parameters': ['theta', 'phi', 'lam'],
#             'qasm_def': 'gate u3(theta,phi,lam) q { U(theta,phi,lam) q; }'},
#            {'conditional': True,
#             'description': 'Single-qubit gate with three rotation angles',
#             'name': 'u',
#             'parameters': ['theta', 'phi', 'lam'],
#             'qasm_def': 'gate u(theta,phi,lam) q { U(theta,phi,lam) q; }'},
#            {'conditional': True,
#             'description': 'Single-qubit rotation about the Z axis',
#             'name': 'p',
#             'parameters': ['lam'],
#             'qasm_def': 'gate p(lam) q { U(0,0,lam) q; }'},
#            {'conditional': True,
#             'description': 'Rotation around an axis in x-y plane',
#             'name': 'r',
#             'parameters': ['theta', 'phi'],
#             'qasm_def': 'gate r(theta,phi) q { U(theta,phi-pi/2,-phi+pi/2) q; '
#                         '}'},
#            {'conditional': True,
#             'description': 'Rotation around the X axis',
#             'name': 'rx',
#             'parameters': ['theta'],
#             'qasm_def': 'gate rx(theta) q { U(theta,-pi/2,pi/2) q; }'},
#            {'conditional': True,
#             'description': 'Rotation around the Y axis',
#             'name': 'ry',
#             'parameters': ['theta'],
#             'qasm_def': 'gate ry(theta) q { U(theta,0,0) q; }'},
#            {'conditional': True,
#             'description': 'Rotation around the Z axis',
#             'name': 'rz',
#             'parameters': ['phi'],
#             'qasm_def': 'gate rz(phi) q { U(0,0,phi) q; }'},
#            {'conditional': True,
#             'description': 'Two-qubit Controlled-NOT gate',
#             'name': 'cx',
#             'parameters': [],
#             'qasm_def': 'gate cx c,t { CX c,t; }'},
#            {'conditional': True,
#             'description': 'Two-qubit Controlled-Y gate',
#             'name': 'cy',
#             'parameters': [],
#             'qasm_def': 'gate cy a,b { U(0,0,-pi/2) b; CX a,b; U(0,0,pi/2) b; '
#                         '}'},
#            {'conditional': True,
#             'description': 'Two-qubit Controlled-Z gate',
#             'name': 'cz',
#             'parameters': [],
#             'qasm_def': 'gate cz a,b { U(pi/2,0,pi) b; CX a,b; U(pi/2,0,pi) b; '
#                         '}'},
#            {'conditional': True,
#             'description': 'Two-qubit Controlled Sqrt(X) gate',
#             'name': 'csx',
#             'parameters': [],
#             'qasm_def': 'gate csx a,b { U(pi/2,0,pi) b; CX a,b; U(pi/2,0,pi) '
#                         'b; U(0,0,lam/2) a; CX a,b; U(0,0,-lam/2) b; CX a,b; '
#                         'U(0,0,lam/2) b; U(pi/2,0,pi) b; }'},
#            {'conditional': True,
#             'description': 'Controlled-Phase gate',
#             'name': 'cp',
#             'parameters': [],
#             'qasm_def': 'gate cp(theta) a,b { U(0,0,theta/2) a; CX a,b; '
#                         'U(0,0,-theta/2) b; CX a,b; U(0,0,theta/2) b; }'},
#            {'conditional': True,
#             'description': 'Single-qubit identity gate',
#             'name': 'id',
#             'parameters': [],
#             'qasm_def': 'gate id a { U(0,0,0) a; }'},
#            {'conditional': True,
#             'description': 'Single-qubit Pauli-X gate',
#             'name': 'x',
#             'parameters': [],
#             'qasm_def': 'gate x a { U(pi,0,pi) a; }'},
#            {'conditional': True,
#             'description': 'Single-qubit Pauli-Y gate',
#             'name': 'y',
#             'parameters': [],
#             'qasm_def': 'gate y a { U(pi,pi/2,pi/2) a; }'},
#            {'conditional': True,
#             'description': 'Single-qubit Pauli-Z gate',
#             'name': 'z',
#             'parameters': [],
#             'qasm_def': 'gate z a { U(0,0,pi) a; }'},
#            {'conditional': True,
#             'description': 'Single-qubit Hadamard gate',
#             'name': 'h',
#             'parameters': [],
#             'qasm_def': 'gate h q { U(pi/2,0,pi) q; }'},
#            {'conditional': True,
#             'description': 'Single-qubit phase gate',
#             'name': 's',
#             'parameters': [],
#             'qasm_def': 'gate s q { U(0,0,pi/2) q; }'},
#            {'conditional': True,
#             'description': 'Single-qubit adjoint phase gate',
#             'name': 'sdg',
#             'parameters': [],
#             'qasm_def': 'gate sdg q { U(0,0,-pi/2) q; }'},
#            {'conditional': True,
#             'description': 'Single-qubit Sqrt(X) gate',
#             'name': 'sx',
#             'parameters': [],
#             'qasm_def': 'gate sx q { U(pi/2,-pi/2,pi/2) q; }'},
#            {'conditional': True,
#             'description': 'Single-qubit T gate',
#             'name': 't',
#             'parameters': [],
#             'qasm_def': 'gate t q { U(0,0,pi/4) q; }'},
#            {'conditional': True,
#             'description': 'Single-qubit adjoint T gate',
#             'name': 'tdg',
#             'parameters': [],
#             'qasm_def': 'gate t q { U(0,0,-pi/4) q; }'},
#            {'conditional': True,
#             'description': 'Two-qubit SWAP gate',
#             'name': 'swap',
#             'parameters': [],
#             'qasm_def': 'TODO'},
#            {'conditional': True,
#             'description': 'Three-qubit Toffoli gate',
#             'name': 'ccx',
#             'parameters': [],
#             'qasm_def': 'TODO'},
#            {'conditional': True,
#             'description': 'Three-qubit Fredkin (controlled-SWAP) gate',
#             'name': 'cswap',
#             'parameters': [],
#             'qasm_def': 'TODO'},
#            {'conditional': True,
#             'description': 'N-qubit unitary gate. The parameter is the N-qubit '
#                            'matrix to apply.',
#             'name': 'unitary',
#             'parameters': ['matrix'],
#             'qasm_def': 'unitary(matrix) q1, q2,...'},
#            {'conditional': True,
#             'description': 'N-qubit diagonal unitary gate. The parameters are '
#                            'the diagonal entries of the N-qubit matrix to '
#                            'apply.',
#             'name': 'diagonal',
#             'parameters': ['diag_elements'],
#             'qasm_def': 'TODO'},
#            {'conditional': False,
#             'description': 'N-qubit state initialize. Resets qubits then sets '
#                            'statevector to the parameter vector.',
#             'name': 'initialize',
#             'parameters': ['vector'],
#             'qasm_def': 'initialize(vector) q1, q2,...'},
#            {'conditional': True,
#             'description': 'Two-qubit Controlled-u1 gate',
#             'name': 'cu1',
#             'parameters': ['lam'],
#             'qasm_def': 'gate cu1(lam) a,b { U(0,0,lam/2) a; CX a,b; '
#                         'U(0,0,-lam/2) b; CX a,b; U(0,0,lam/2) b; }'},
#            {'conditional': True,
#             'description': 'Two-qubit Controlled-u2 gate',
#             'name': 'cu2',
#             'parameters': ['phi', 'lam'],
#             'qasm_def': 'TODO'},
#            {'conditional': True,
#             'description': 'Two-qubit Controlled-u3 gate',
#             'name': 'cu3',
#             'parameters': ['theta', 'phi', 'lam'],
#             'qasm_def': 'TODO'},
#            {'conditional': True,
#             'description': 'Two-qubit XX-rotation gate',
#             'name': 'rxx',
#             'parameters': ['theta'],
#             'qasm_def': 'gate rxx a,b { U(pi/2,0,pi) a; U(pi/2,0,pi) b; CX '
#                         'a,b; U(0,0,phi) b; CX a,b; U(pi/2,0,pi) b; '
#                         'U(pi/2,0,pi) a; }'},
#            {'conditional': True,
#             'description': 'Two-qubit YY-rotation gate',
#             'name': 'ryy',
#             'parameters': ['theta'],
#             'qasm_def': 'gate ryy a,b { U(pi/2,-pi/2,pi/2) a; '
#                         'U(pi/2,-pi/2,pi/2) b; CX a,b; U(0,0,theta) q; CX a,b; '
#                         'U(-pi/2,-pi/2,pi/2) a; U(-pi/2,-pi/2,pi/2) b; }'},
#            {'conditional': True,
#             'description': 'Two-qubit ZZ-rotation gate',
#             'name': 'rzz',
#             'parameters': ['theta'],
#             'qasm_def': 'gate rzz a,b { CX a,b; U(0,0,theta) b; CX a,b; }'},
#            {'conditional': True,
#             'description': 'Two-qubit ZX-rotation gate',
#             'name': 'rzx',
#             'parameters': ['theta'],
#             'qasm_def': 'gate rzx a,b { U(pi/2,0,pi) b; CX a,b; U(0,0,theta) '
#                         'b; CX a,b; U(pi/2,0,pi) b; }'},
#            {'conditional': True,
#             'description': 'N-qubit multi-controlled-X gate',
#             'name': 'mcx',
#             'parameters': [],
#             'qasm_def': 'TODO'},
#            {'conditional': True,
#             'description': 'N-qubit multi-controlled-Y gate',
#             'name': 'mcy',
#             'parameters': [],
#             'qasm_def': 'TODO'},
#            {'conditional': True,
#             'description': 'N-qubit multi-controlled-Z gate',
#             'name': 'mcz',
#             'parameters': [],
#             'qasm_def': 'TODO'},
#            {'conditional': True,
#             'description': '',
#             'name': 'mcsx',
#             'parameters': [],
#             'qasm_def': 'TODO'},
#            {'conditional': True,
#             'description': 'Multi-controlled-Phase gate',
#             'name': 'mcp',
#             'parameters': ['lam'],
#             'qasm_def': 'TODO'},
#            {'conditional': True,
#             'description': 'N-qubit multi-controlled-u1 gate',
#             'name': 'mcu1',
#             'parameters': ['lam'],
#             'qasm_def': 'TODO'},
#            {'conditional': True,
#             'description': 'N-qubit multi-controlled-u2 gate',
#             'name': 'mcu2',
#             'parameters': ['phi', 'lam'],
#             'qasm_def': 'TODO'},
#            {'conditional': True,
#             'description': 'N-qubit multi-controlled-u3 gate',
#             'name': 'mcu3',
#             'parameters': ['theta', 'phi', 'lam'],
#             'qasm_def': 'TODO'},
#            {'conditional': True,
#             'description': 'Multiple-Controlled X rotation gate',
#             'name': 'mcrx',
#             'parameters': ['theta'],
#             'qasm_def': 'TODO'},
#            {'conditional': True,
#             'description': 'Multiple-Controlled Y rotation gate',
#             'name': 'mcry',
#             'parameters': ['theta'],
#             'qasm_def': 'TODO'},
#            {'conditional': True,
#             'description': 'Multiple-Controlled Z rotation gate',
#             'name': 'mcrz',
#             'parameters': ['theta'],
#             'qasm_def': 'TODO'},
#            {'conditional': True,
#             'description': 'Multiple-Controlled rotation gate',
#             'name': 'mcr',
#             'parameters': [],
#             'qasm_def': 'TODO'},
#            {'conditional': True,
#             'description': 'N-qubit multi-controlled-SWAP gate',
#             'name': 'mcswap',
#             'parameters': [],
#             'qasm_def': 'TODO'},
#            {'conditional': True,
#             'description': 'N-qubit multi-plexer gate. The input parameters '
#                            'are the gates for each value.',
#             'name': 'multiplexer',
#             'parameters': ['mat1', 'mat2', '...'],
#             'qasm_def': 'TODO'},
#            {'conditional': True,
#             'description': 'N-qubit Kraus error instruction. The input '
#                            'parameters are the Kraus matrices.',
#             'name': 'kraus',
#             'parameters': ['mat1', 'mat2', '...'],
#             'qasm_def': 'TODO'},
#            {'conditional': True,
#             'description': 'Delay instruction',
#             'name': 'delay',
#             'parameters': [],
#             'qasm_def': 'TODO'},
#            {'conditional': False,
#             'description': 'N-bit classical readout error instruction. The '
#                            'input parameter is the readout error probability '
#                            'matrix.',
#             'name': 'roerror',
#             'parameters': ['matrix'],
#             'qasm_def': 'TODO'}],
#  'input_allowed': ['job', 'runtime'],
#  'live_data': False,
#  'local': False,
#  'max_experiments': 300,
#  'max_shots': 20000,
#  'memory': True,
#  'n_qubits': 32,
#  'online_date': datetime.datetime(2019, 5, 2, 8, 15, tzinfo=tzutc()),
#  'open_pulse': False,
#  'pulse_num_channels': 9,
#  'pulse_num_qubits': 3,
#  'simulator': True}

# %%
circuit = QuantumCircuit(8, 8)

circuit.x(0)
circuit.x(6)
circuit.h(3)
circuit.cx(3, 1)
for i in range(8):
    circuit.measure(i, i)

backend = Aer.get_backend("aer_simulator")

job = backend.run(circuit)

result = job.result()
counts = result.get_counts(circuit)
print(f"qbit counts: {counts}")
print(f"'A' = {ord('A'):08b}, 'K' = {ord('K'):08b}")

circuit.draw("mpl")
# Out:
# qbit counts: {'01001011': 516, '01000001': 508}
# 'A' = 01000001, 'K' = 01001011
# C:\Users\alaga\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\qiskit\visualization\circuit\matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
from qiskit.visualization import plot_histogram

plot_histogram(counts)

# %%
import matplotlib.pyplot as plt

sum = 0
for value in counts.values():
    sum += value

plt.rc("font", family="monospace")
plt.annotate(
    "A",
    (0.5, 0.5),
    va="center",
    ha="center",
    color=(0, 0, 0, counts[f"{ord('A'):08b}"] / sum),
    size=300,
)
plt.annotate(
    "K",
    (0.5, 0.5),
    va="center",
    ha="center",
    color=(0, 0, 0, counts[f"{ord('K'):08b}"] / sum),
    size=300,
)
plt.axis("off")
plt.show()

# %%
# Real machine
# 'A' = 01000001, 'K' = 01001011
# bit 7, bit 6, bit 5 are constant

from pprint import pprint
from qiskit import execute, IBMQ, QuantumCircuit
from qiskit.visualization import plot_histogram


circuit = QuantumCircuit(5, 5)

circuit.x(0)
circuit.h(3)
circuit.cx(3, 1)
for i in range(5):
    circuit.measure(i, i)

provider = IBMQ.load_account()
pprint(provider.backends())
# backend_overview()

real_backend = provider.get_backend("ibm_nairobi")
real_job = execute(circuit, real_backend, shots=1024)

real_job_id = real_job.job_id()
real_result = real_backend.retrieve_job(real_job_id).result()
real_counts = real_result.get_counts()

real_counts = {
    f"{ord('A'):08b}": real_counts["00001"],
    f"{ord('K'):08b}": real_counts["01011"],
}

plot_histogram(real_counts)
# Out:
# ibmqfactory.load_account:WARNING:2023-11-23 19:14:59,797: Credentials are already in use. The existing account in the session will be replaced.
# [<IBMQSimulator('ibmq_qasm_simulator') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQSimulator('simulator_statevector') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQSimulator('simulator_mps') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQSimulator('simulator_extended_stabilizer') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQSimulator('simulator_stabilizer') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibm_lagos') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibm_nairobi') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibm_perth') from IBMQ(hub='ibm-q', group='open', project='main')>,
#  <IBMQBackend('ibm_brisbane') from IBMQ(hub='ibm-q', group='open', project='main')>]
